# %% [markdown]
# ## **LinkedIn Job Postings Analysis**
#
# In this notebook i will attempt to merge, clean the data, and doing basic data visualization for analysis.
#
# I hope you all enjoy my notebook, please upvote if you like it. Thanks

# %% [markdown]
# # Importing Dependencies

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # for plotting chart
from functools import reduce # module to help merge multiple dataframe
from wordcloud import WordCloud # module to print word cloud

# %% [markdown]
# # Data Collecting & Pre-Processing

# %%
# main dataframe
job_postings_data = pd.read_csv("/kaggle/input/linkedin-job-postings/job_postings.csv")
job_postings_data
# Out:
#            job_id  company_id                                  title  \
# 0        85008768         NaN               Licensed Insurance Agent
# 1       133114754  77766802.0                          Sales Manager
# 2       133196985   1089558.0                     Model Risk Auditor
# 3       381055942  96654609.0                       Business Manager
# 4       529257371   1244539.0                    NY Studio Assistant
# ...           ...         ...                                    ...
# 15881  3701373516  74718032.0                  Sanitation Technician
# 15882  3701373522     38897.0                         Unit Secretary
# 15883  3701373523     38897.0                Radiology Aide, Perdiem
# 15884  3701373524      2623.0                            MRI Manager
# 15885  3701373527     84659.0  Area Director of Business Development
#
#                                              description  max_salary  \
# 0      While many industries were hurt by the last fe...     52000.0
# 1      Are you a dynamic and creative marketing profe...         NaN
# 2      Join Us as a Model Risk Auditor – Showcase You...         NaN
# 3      Business ManagerFirst Baptist Church ForneyFor...         NaN
# 4      YOU COULD BE ONE OF THE MAGIC MAKERS\nKen Fulk...         NaN
# ...                                                  ...         ...
# 15881  Location:\n\nWest Columbia, SC, US, 29172\n\n2...         NaN
# 15882  Job Title: Unit Secretary\nDepartment: Nursing...         NaN
# 15883  Job Title: Radiology Aide, Perdiem\nDepartment...         NaN
# 15884  Grade 105\nJob Type: Officer of Administration...    135000.0
# 15885  Nexion Health Management affiliates operate 56...         NaN
#
#        med_salary  min_salary pay_period formatted_work_type  \
# 0             NaN     45760.0     YEARLY           Full-time
# 1             NaN         NaN        NaN           Full-time
# 2             NaN         NaN        NaN            Contract
# 3             NaN         NaN        NaN           Full-time
# 4             NaN         NaN        NaN           Full-time
# ...           ...         ...        ...                 ...
# 15881         NaN         NaN        NaN           Part-time
# 15882         NaN         NaN        NaN           Full-time
# 15883         NaN         NaN        NaN           Part-time
# 15884         NaN    110000.0     YEARLY           Full-time
# 15885         NaN         NaN        NaN           Full-time
#
#                 location  ...        expiry  closed_time  \
# 0              Chico, CA  ...  1.710000e+12          NaN
# 1      Santa Clarita, CA  ...  1.700000e+12          NaN
# 2           New York, NY  ...  1.700000e+12          NaN
# 3             Forney, TX  ...  1.700000e+12          NaN
# 4           New York, NY  ...  1.710000e+12          NaN
# ...                  ...  ...           ...          ...
# 15881  West Columbia, SC  ...  1.700000e+12          NaN
# 15882        Teaneck, NJ  ...  1.700000e+12          NaN
# 15883        Teaneck, NJ  ...  1.700000e+12          NaN
# 15884       New York, NY  ...  1.700000e+12          NaN
# 15885      Vicksburg, MS  ...  1.700000e+12          NaN
#
#        formatted_experience_level  skills_desc   listed_time  \
# 0                             NaN          NaN  1.690000e+12
# 1                             NaN          NaN  1.690000e+12
# 2                             NaN          NaN  1.690000e+12
# 3                             NaN          NaN  1.690000e+12
# 4                             NaN          NaN  1.690000e+12
# ...                           ...          ...           ...
# 15881                 Entry level          NaN  1.690000e+12
# 15882                 Entry level          NaN  1.690000e+12
# 15883                 Entry level          NaN  1.690000e+12
# 15884            Mid-Senior level          NaN  1.690000e+12
# 15885                         NaN          NaN  1.690000e+12
#
#                    posting_domain sponsored  work_type  currency  \
# 0                             NaN         1  FULL_TIME       USD
# 1                             NaN         0  FULL_TIME       NaN
# 2                             NaN         0   CONTRACT       NaN
# 3                             NaN         0  FULL_TIME       NaN
# 4                             NaN         1  FULL_TIME       NaN
# ...                           ...       ...        ...       ...
# 15881   aspirebakeriescareers.com         0  PART_TIME       NaN
# 15882      recruiting.ultipro.com         0  FULL_TIME       NaN
# 15883      recruiting.ultipro.com         0  PART_TIME       NaN
# 15884  opportunities.columbia.edu         0  FULL_TIME       USD
# 15885                         NaN         0  FULL_TIME       NaN
#
#       compensation_type
# 0           BASE_SALARY
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 15881               NaN
# 15882               NaN
# 15883               NaN
# 15884       BASE_SALARY
# 15885               NaN
#
# [15886 rows x 27 columns]

# %% [markdown]
# let's check if there is duplicate and null in <code>job_id</code>

# %%
duplicates = job_postings_data['job_id'].duplicated()
num_duplicates = duplicates.sum()
num_duplicates
# Out:
# 0

# %%
job_postings_data['job_id'].isnull().sum()
# Out:
# 0

# %% [markdown]
# there is no duplicate and no null so move on to the next step

# %% [markdown]
# in <code>benefits.csv</code> there exist duplicate <code>job_id</code> and unrelated <code>inferred</code> column so lets combine the duplicate <code>job_id</code> and remove the <code>inferred</code> column

# %%
job_benefits_data = pd.read_csv("/kaggle/input/linkedin-job-postings/job_details/benefits.csv")
job_benefits_data = job_benefits_data.drop('inferred', axis=1) # remove 'inferred' column
job_benefits_data = job_benefits_data.groupby('job_id')['type'].agg(lambda x: ', '.join(x)).reset_index() # aggregate same job benefits

# %% [markdown]
# then we merge our main dataframe with job benefits dataframe

# %%
job_postings_data = job_postings_data.merge(job_benefits_data, on="job_id", how="left")
job_postings_data
# Out:
#            job_id  company_id                                  title  \
# 0        85008768         NaN               Licensed Insurance Agent
# 1       133114754  77766802.0                          Sales Manager
# 2       133196985   1089558.0                     Model Risk Auditor
# 3       381055942  96654609.0                       Business Manager
# 4       529257371   1244539.0                    NY Studio Assistant
# ...           ...         ...                                    ...
# 15881  3701373516  74718032.0                  Sanitation Technician
# 15882  3701373522     38897.0                         Unit Secretary
# 15883  3701373523     38897.0                Radiology Aide, Perdiem
# 15884  3701373524      2623.0                            MRI Manager
# 15885  3701373527     84659.0  Area Director of Business Development
#
#                                              description  max_salary  \
# 0      While many industries were hurt by the last fe...     52000.0
# 1      Are you a dynamic and creative marketing profe...         NaN
# 2      Join Us as a Model Risk Auditor – Showcase You...         NaN
# 3      Business ManagerFirst Baptist Church ForneyFor...         NaN
# 4      YOU COULD BE ONE OF THE MAGIC MAKERS\nKen Fulk...         NaN
# ...                                                  ...         ...
# 15881  Location:\n\nWest Columbia, SC, US, 29172\n\n2...         NaN
# 15882  Job Title: Unit Secretary\nDepartment: Nursing...         NaN
# 15883  Job Title: Radiology Aide, Perdiem\nDepartment...         NaN
# 15884  Grade 105\nJob Type: Officer of Administration...    135000.0
# 15885  Nexion Health Management affiliates operate 56...         NaN
#
#        med_salary  min_salary pay_period formatted_work_type  \
# 0             NaN     45760.0     YEARLY           Full-time
# 1             NaN         NaN        NaN           Full-time
# 2             NaN         NaN        NaN            Contract
# 3             NaN         NaN        NaN           Full-time
# 4             NaN         NaN        NaN           Full-time
# ...           ...         ...        ...                 ...
# 15881         NaN         NaN        NaN           Part-time
# 15882         NaN         NaN        NaN           Full-time
# 15883         NaN         NaN        NaN           Part-time
# 15884         NaN    110000.0     YEARLY           Full-time
# 15885         NaN         NaN        NaN           Full-time
#
#                 location  ...  closed_time  formatted_experience_level  \
# 0              Chico, CA  ...          NaN                         NaN
# 1      Santa Clarita, CA  ...          NaN                         NaN
# 2           New York, NY  ...          NaN                         NaN
# 3             Forney, TX  ...          NaN                         NaN
# 4           New York, NY  ...          NaN                         NaN
# ...                  ...  ...          ...                         ...
# 15881  West Columbia, SC  ...          NaN                 Entry level
# 15882        Teaneck, NJ  ...          NaN                 Entry level
# 15883        Teaneck, NJ  ...          NaN                 Entry level
# 15884       New York, NY  ...          NaN            Mid-Senior level
# 15885      Vicksburg, MS  ...          NaN                         NaN
#
#        skills_desc   listed_time              posting_domain sponsored  \
# 0              NaN  1.690000e+12                         NaN         1
# 1              NaN  1.690000e+12                         NaN         0
# 2              NaN  1.690000e+12                         NaN         0
# 3              NaN  1.690000e+12                         NaN         0
# 4              NaN  1.690000e+12                         NaN         1
# ...            ...           ...                         ...       ...
# 15881          NaN  1.690000e+12   aspirebakeriescareers.com         0
# 15882          NaN  1.690000e+12      recruiting.ultipro.com         0
# 15883          NaN  1.690000e+12      recruiting.ultipro.com         0
# 15884          NaN  1.690000e+12  opportunities.columbia.edu         0
# 15885          NaN  1.690000e+12                         NaN         0
#
#        work_type  currency  compensation_type  \
# 0      FULL_TIME       USD        BASE_SALARY
# 1      FULL_TIME       NaN                NaN
# 2       CONTRACT       NaN                NaN
# 3      FULL_TIME       NaN                NaN
# 4      FULL_TIME       NaN                NaN
# ...          ...       ...                ...
# 15881  PART_TIME       NaN                NaN
# 15882  FULL_TIME       NaN                NaN
# 15883  PART_TIME       NaN                NaN
# 15884  FULL_TIME       USD        BASE_SALARY
# 15885  FULL_TIME       NaN                NaN
#
#                                                     type
# 0      Medical insurance, Vision insurance, Dental in...
# 1            Medical insurance, 401(k), Vision insurance
# 2                                                    NaN
# 3                                                    NaN
# 4      Medical insurance, Vision insurance, Dental in...
# ...                                                  ...
# 15881                                                NaN
# 15882                                                NaN
# 15883                                                NaN
# 15884                                                NaN
# 15885  Medical insurance, Vision insurance, Dental in...
#
# [15886 rows x 28 columns]

# %% [markdown]
# we will also merge duplicate <code>job_id</code> on <code>job_skills.csv</code> and join them into the main dataframe

# %%
job_skills_data = pd.read_csv("/kaggle/input/linkedin-job-postings/job_details/job_skills.csv")
job_skills_data = job_skills_data.groupby('job_id')['skill_abr'].agg(lambda x: ', '.join(x)).reset_index() # aggregate same job skills

job_postings_data = job_postings_data.merge(job_skills_data, on="job_id", how="left")
job_postings_data
# Out:
#            job_id  company_id                                  title  \
# 0        85008768         NaN               Licensed Insurance Agent
# 1       133114754  77766802.0                          Sales Manager
# 2       133196985   1089558.0                     Model Risk Auditor
# 3       381055942  96654609.0                       Business Manager
# 4       529257371   1244539.0                    NY Studio Assistant
# ...           ...         ...                                    ...
# 15881  3701373516  74718032.0                  Sanitation Technician
# 15882  3701373522     38897.0                         Unit Secretary
# 15883  3701373523     38897.0                Radiology Aide, Perdiem
# 15884  3701373524      2623.0                            MRI Manager
# 15885  3701373527     84659.0  Area Director of Business Development
#
#                                              description  max_salary  \
# 0      While many industries were hurt by the last fe...     52000.0
# 1      Are you a dynamic and creative marketing profe...         NaN
# 2      Join Us as a Model Risk Auditor – Showcase You...         NaN
# 3      Business ManagerFirst Baptist Church ForneyFor...         NaN
# 4      YOU COULD BE ONE OF THE MAGIC MAKERS\nKen Fulk...         NaN
# ...                                                  ...         ...
# 15881  Location:\n\nWest Columbia, SC, US, 29172\n\n2...         NaN
# 15882  Job Title: Unit Secretary\nDepartment: Nursing...         NaN
# 15883  Job Title: Radiology Aide, Perdiem\nDepartment...         NaN
# 15884  Grade 105\nJob Type: Officer of Administration...    135000.0
# 15885  Nexion Health Management affiliates operate 56...         NaN
#
#        med_salary  min_salary pay_period formatted_work_type  \
# 0             NaN     45760.0     YEARLY           Full-time
# 1             NaN         NaN        NaN           Full-time
# 2             NaN         NaN        NaN            Contract
# 3             NaN         NaN        NaN           Full-time
# 4             NaN         NaN        NaN           Full-time
# ...           ...         ...        ...                 ...
# 15881         NaN         NaN        NaN           Part-time
# 15882         NaN         NaN        NaN           Full-time
# 15883         NaN         NaN        NaN           Part-time
# 15884         NaN    110000.0     YEARLY           Full-time
# 15885         NaN         NaN        NaN           Full-time
#
#                 location  ...  formatted_experience_level  skills_desc  \
# 0              Chico, CA  ...                         NaN          NaN
# 1      Santa Clarita, CA  ...                         NaN          NaN
# 2           New York, NY  ...                         NaN          NaN
# 3             Forney, TX  ...                         NaN          NaN
# 4           New York, NY  ...                         NaN          NaN
# ...                  ...  ...                         ...          ...
# 15881  West Columbia, SC  ...                 Entry level          NaN
# 15882        Teaneck, NJ  ...                 Entry level          NaN
# 15883        Teaneck, NJ  ...                 Entry level          NaN
# 15884       New York, NY  ...            Mid-Senior level          NaN
# 15885      Vicksburg, MS  ...                         NaN          NaN
#
#         listed_time              posting_domain sponsored  work_type currency  \
# 0      1.690000e+12                         NaN         1  FULL_TIME      USD
# 1      1.690000e+12                         NaN         0  FULL_TIME      NaN
# 2      1.690000e+12                         NaN         0   CONTRACT      NaN
# 3      1.690000e+12                         NaN         0  FULL_TIME      NaN
# 4      1.690000e+12                         NaN         1  FULL_TIME      NaN
# ...             ...                         ...       ...        ...      ...
# 15881  1.690000e+12   aspirebakeriescareers.com         0  PART_TIME      NaN
# 15882  1.690000e+12      recruiting.ultipro.com         0  FULL_TIME      NaN
# 15883  1.690000e+12      recruiting.ultipro.com         0  PART_TIME      NaN
# 15884  1.690000e+12  opportunities.columbia.edu         0  FULL_TIME      USD
# 15885  1.690000e+12                         NaN         0  FULL_TIME      NaN
#
#        compensation_type                                               type  \
# 0            BASE_SALARY  Medical insurance, Vision insurance, Dental in...
# 1                    NaN        Medical insurance, 401(k), Vision insurance
# 2                    NaN                                                NaN
# 3                    NaN                                                NaN
# 4                    NaN  Medical insurance, Vision insurance, Dental in...
# ...                  ...                                                ...
# 15881                NaN                                                NaN
# 15882                NaN                                                NaN
# 15883                NaN                                                NaN
# 15884        BASE_SALARY                                                NaN
# 15885                NaN  Medical insurance, Vision insurance, Dental in...
#
#            skill_abr
# 0           SALE, BD
# 1           SALE, BD
# 2          ACCT, FIN
# 3                NaN
# 4      DSGN, ART, IT
# ...              ...
# 15881        ENG, IT
# 15882            ADM
# 15883           HCPR
# 15884           OTHR
# 15885       BD, SALE
#
# [15886 rows x 29 columns]

# %% [markdown]
# the job_details data is done, next we will pre-process the company_details data

# %%
company_data = pd.read_csv("/kaggle/input/linkedin-job-postings/company_details/companies.csv")

company_industries_data = pd.read_csv("/kaggle/input/linkedin-job-postings/company_details/company_industries.csv")
company_industries_data = company_industries_data.groupby('company_id')['industry'].agg(lambda x: ', '.join(x)).reset_index() # aggregate same company industries

company_specialities_data = pd.read_csv("/kaggle/input/linkedin-job-postings/company_details/company_specialities.csv")
company_specialities_data = company_specialities_data.groupby('company_id')['speciality'].agg(lambda x: ', '.join(x)).reset_index() # aggregate same company specialities

employee_counts_data = pd.read_csv("/kaggle/input/linkedin-job-postings/company_details/employee_counts.csv")
employee_counts_data = employee_counts_data.groupby('company_id')['time_recorded'].max().reset_index() # get newest data based on 'time_recorded' column

company_data = company_data.merge(company_industries_data, on="company_id", how="left")
company_data = company_data.merge(company_specialities_data, on="company_id", how="left")
company_data = company_data.merge(employee_counts_data, on="company_id", how="left")
company_data
# Out:
#       company_id                                    name  \
# 0           1009                                     IBM
# 1           1016                           GE HealthCare
# 2           1021                                GE Power
# 3           1025              Hewlett Packard Enterprise
# 4           1028                                  Oracle
# ...          ...                                     ...
# 6058  3700144594                                  BYREDO
# 6059  3700144710  Pros2Plan, a division of Spinnaker SCA
# 6060  3700147810                       Ascendo Resources
# 6061  3700150295                          The Crox Group
# 6062  3700152513                       Sidley Austin LLP
#
#                                             description  company_size  \
# 0     At IBM, we do more than work. We create. We cr...           7.0
# 1     Every day millions of people feel the impact o...           7.0
# 2     GE Power, part of GE Vernova, is a world energ...           7.0
# 3     Official LinkedIn of Hewlett Packard Enterpris...           7.0
# 4     We’re a cloud technology company that provides...           7.0
# ...                                                 ...           ...
# 6058  "Beauty can be many things to many people. Our...           3.0
# 6059  Pros2Plan, a  division of Spinnaker Services L...           2.0
# 6060  Ascendo Resources is a certified minority owne...           3.0
# 6061  The Crox Group, Head Quartered in Chicago, wit...           2.0
# 6062  Sidley is an elite global law firm with nearly...           5.0
#
#          state country              city zip_code  \
# 0           NY      US  Armonk, New York    10504
# 1            0      US           Chicago        0
# 2           NY      US       Schenectady    12345
# 3        Texas      US           Houston    77389
# 4        Texas      US            Austin    78741
# ...        ...     ...               ...      ...
# 6058         0       0                 0        0
# 6059        CO      US           Boulder    80303
# 6060        FL      US      Coral Gables    33134
# 6061  Illinois      US       Lincolnwood    60712
# 6062  Illinois      US           Chicago    60603
#
#                                     address  \
# 0     International Business Machines Corp.
# 1                                         -
# 2                              1 River Road
# 3               1701 E Mossy Oaks Rd Spring
# 4                           2300 Oracle Way
# ...                                     ...
# 6058                                      0
# 6059                                      0
# 6060                       2 Alhambra Plaza
# 6061                     6818 N Lincoln Ave
# 6062                     One South Dearborn
#
#                                                     url  \
# 0                  https://www.linkedin.com/company/ibm
# 1         https://www.linkedin.com/company/gehealthcare
# 2              https://www.linkedin.com/company/gepower
# 3     https://www.linkedin.com/company/hewlett-packa...
# 4               https://www.linkedin.com/company/oracle
# ...                                                 ...
# 6058            https://www.linkedin.com/company/byredo
# 6059         https://www.linkedin.com/company/pros2plan
# 6060  https://www.linkedin.com/company/ascendoresources
# 6061    https://www.linkedin.com/company/the-crox-group
# 6062     https://www.linkedin.com/company/sidley-austin
#
#                                                industry  \
# 0     Information Technology & Services, Information...
# 1     Hospital & Health Care, Hospital & Health Care...
# 2                              Renewables & Environment
# 3                     Information Technology & Services
# 4     Information Technology & Services, Information...
# ...                                                 ...
# 6058                                                NaN
# 6059                                                NaN
# 6060                                                NaN
# 6061                                                NaN
# 6062                                                NaN
#
#                                              speciality  time_recorded
# 0     Cloud, Mobile, Cognitive, Security, Research, ...   1.692851e+09
# 1     Healthcare, Biotechnology, Healthcare, Biotech...   1.692861e+09
# 2     Distributed Power, Gasification, Generators, H...   1.692866e+09
# 3                                                   NaN   1.692840e+09
# 4     enterprise, software, applications, database, ...   1.692867e+09
# ...                                                 ...            ...
# 6058                                                NaN            NaN
# 6059                                                NaN            NaN
# 6060                                                NaN            NaN
# 6061                                                NaN            NaN
# 6062                                                NaN            NaN
#
# [6063 rows x 13 columns]

# %% [markdown]
# Finally we merge job postings and company data together and we have data about company that post jobs on linkedIn.

# %%
merged_data = job_postings_data.merge(company_data, on="company_id", how="left")
merged_data
# Out:
#            job_id  company_id                                  title  \
# 0        85008768         NaN               Licensed Insurance Agent
# 1       133114754  77766802.0                          Sales Manager
# 2       133196985   1089558.0                     Model Risk Auditor
# 3       381055942  96654609.0                       Business Manager
# 4       529257371   1244539.0                    NY Studio Assistant
# ...           ...         ...                                    ...
# 15881  3701373516  74718032.0                  Sanitation Technician
# 15882  3701373522     38897.0                         Unit Secretary
# 15883  3701373523     38897.0                Radiology Aide, Perdiem
# 15884  3701373524      2623.0                            MRI Manager
# 15885  3701373527     84659.0  Area Director of Business Development
#
#                                            description_x  max_salary  \
# 0      While many industries were hurt by the last fe...     52000.0
# 1      Are you a dynamic and creative marketing profe...         NaN
# 2      Join Us as a Model Risk Auditor – Showcase You...         NaN
# 3      Business ManagerFirst Baptist Church ForneyFor...         NaN
# 4      YOU COULD BE ONE OF THE MAGIC MAKERS\nKen Fulk...         NaN
# ...                                                  ...         ...
# 15881  Location:\n\nWest Columbia, SC, US, 29172\n\n2...         NaN
# 15882  Job Title: Unit Secretary\nDepartment: Nursing...         NaN
# 15883  Job Title: Radiology Aide, Perdiem\nDepartment...         NaN
# 15884  Grade 105\nJob Type: Officer of Administration...    135000.0
# 15885  Nexion Health Management affiliates operate 56...         NaN
#
#        med_salary  min_salary pay_period formatted_work_type  \
# 0             NaN     45760.0     YEARLY           Full-time
# 1             NaN         NaN        NaN           Full-time
# 2             NaN         NaN        NaN            Contract
# 3             NaN         NaN        NaN           Full-time
# 4             NaN         NaN        NaN           Full-time
# ...           ...         ...        ...                 ...
# 15881         NaN         NaN        NaN           Part-time
# 15882         NaN         NaN        NaN           Full-time
# 15883         NaN         NaN        NaN           Part-time
# 15884         NaN    110000.0     YEARLY           Full-time
# 15885         NaN         NaN        NaN           Full-time
#
#                 location  ...  company_size       state  country  \
# 0              Chico, CA  ...           NaN         NaN      NaN
# 1      Santa Clarita, CA  ...           1.0  California       US
# 2           New York, NY  ...           1.0  New Jersey       US
# 3             Forney, TX  ...           2.0       Texas       US
# 4           New York, NY  ...           1.0  California       US
# ...                  ...  ...           ...         ...      ...
# 15881  West Columbia, SC  ...           5.0  California       US
# 15882        Teaneck, NJ  ...           5.0  New Jersey       US
# 15883        Teaneck, NJ  ...           5.0  New Jersey       US
# 15884       New York, NY  ...           7.0    New York       US
# 15885      Vicksburg, MS  ...           5.0    Maryland       US
#
#                 city zip_code             address  \
# 0                NaN      NaN                 NaN
# 1      Santa Clarita    28358    Constellation Rd
# 2           Somerset    08873    285 Davidson Ave
# 3             Forney    75126     1003 College St
# 4      San Francisco    94103  310 Seventh Street
# ...              ...      ...                 ...
# 15881    Los Angeles    90045    6601 Center Dr W
# 15882        Teaneck    07666    718 Teaneck Road
# 15883        Teaneck    07666    718 Teaneck Road
# 15884       New York        0  630 West 168th St.
# 15885     Sykesville    21784  6937 Warfield Ave.
#
#                                                     url  \
# 0                                                   NaN
# 1        https://www.linkedin.com/company/cargologinllc
# 2         https://www.linkedin.com/company/employvision
# 3           https://www.linkedin.com/company/fbc-forney
# 4        https://www.linkedin.com/company/ken-fulk-inc.
# ...                                                 ...
# 15881  https://www.linkedin.com/company/aspire-bakeries
# 15882         https://www.linkedin.com/company/holyname
# 15883         https://www.linkedin.com/company/holyname
# 15884      https://www.linkedin.com/company/columbiamed
# 15885    https://www.linkedin.com/company/nexion-health
#
#                                                 industry  \
# 0                                                    NaN
# 1                       Transportation/Trucking/Railroad
# 2                                  Staffing & Recruiting
# 3                                 Religious Institutions
# 4                                                 Design
# ...                                                  ...
# 15881  Food Production, Food Production, Food Product...
# 15882     Hospital & Health Care, Hospital & Health Care
# 15883     Hospital & Health Care, Hospital & Health Care
# 15884                             Hospital & Health Care
# 15885                             Hospital & Health Care
#
#                                               speciality time_recorded
# 0                                                    NaN           NaN
# 1      Export & Import Clearance, Bonded Warehousing,...  1.692835e+09
# 2                                                    NaN  1.692772e+09
# 3                                                    NaN  1.692832e+09
# 4                                                    NaN  1.692868e+09
# ...                                                  ...           ...
# 15881                                                NaN  1.692869e+09
# 15882  Cardiovascular, Regional Cancer Center, Emerge...  1.692869e+09
# 15883  Cardiovascular, Regional Cancer Center, Emerge...  1.692869e+09
# 15884  Medicine, Education, Healthcare, Science, Biom...  1.692869e+09
# 15885  Skilled Nursing, Physical Therapy, Occupationa...  1.692869e+09
#
# [15886 rows x 41 columns]

# %%
merged_data.isnull().sum()
# Out:
# job_id                            0
# company_id                      366
# title                             0
# description_x                     1
# max_salary                    10365
# med_salary                    14905
# min_salary                    10365
# pay_period                     9384
# formatted_work_type               0
# location                          0
# applies                        7186
# original_listed_time              0
# remote_allowed                13546
# views                          2763
# job_posting_url                   0
# application_url                6091
# application_type                  0
# expiry                            0
# closed_time                   14958
# formatted_experience_level     4902
# skills_desc                   15742
# listed_time                       0
# posting_domain                 6842
# sponsored                         0
# work_type                         0
# currency                       9384
# compensation_type              9384
# type                          10390
# skill_abr                       637
# name                            416
# description_y                   488
# company_size                   1111
# state                           419
# country                         416
# city                            416
# zip_code                        426
# address                         421
# url                             416
# industry                        443
# speciality                     3499
# time_recorded                   416
# dtype: int64

# %% [markdown]
# next we will eliminate certain column to use for analysis, and then rename the column for better understanding

# %%
choosen_column = ['title','name','description_x','formatted_work_type','location','original_listed_time','application_type','sponsored','description_y','company_size','industry']
merged_data = merged_data[choosen_column]
merged_data
# Out:
#                                        title  \
# 0                   Licensed Insurance Agent
# 1                              Sales Manager
# 2                         Model Risk Auditor
# 3                           Business Manager
# 4                        NY Studio Assistant
# ...                                      ...
# 15881                  Sanitation Technician
# 15882                         Unit Secretary
# 15883                Radiology Aide, Perdiem
# 15884                            MRI Manager
# 15885  Area Director of Business Development
#
#                                             name  \
# 0                                            NaN
# 1                                    CargoLogin.
# 2                              Employvision Inc.
# 3                    First Baptist Church Forney
# 4                                   Ken Fulk Inc
# ...                                          ...
# 15881                            Aspire Bakeries
# 15882                   Holy Name Medical Center
# 15883                   Holy Name Medical Center
# 15884  Columbia University Irving Medical Center
# 15885                              Nexion Health
#
#                                            description_x formatted_work_type  \
# 0      While many industries were hurt by the last fe...           Full-time
# 1      Are you a dynamic and creative marketing profe...           Full-time
# 2      Join Us as a Model Risk Auditor – Showcase You...            Contract
# 3      Business ManagerFirst Baptist Church ForneyFor...           Full-time
# 4      YOU COULD BE ONE OF THE MAGIC MAKERS\nKen Fulk...           Full-time
# ...                                                  ...                 ...
# 15881  Location:\n\nWest Columbia, SC, US, 29172\n\n2...           Part-time
# 15882  Job Title: Unit Secretary\nDepartment: Nursing...           Full-time
# 15883  Job Title: Radiology Aide, Perdiem\nDepartment...           Part-time
# 15884  Grade 105\nJob Type: Officer of Administration...           Full-time
# 15885  Nexion Health Management affiliates operate 56...           Full-time
#
#                 location  original_listed_time    application_type  sponsored  \
# 0              Chico, CA          1.690000e+12  ComplexOnsiteApply          1
# 1      Santa Clarita, CA          1.690000e+12  ComplexOnsiteApply          0
# 2           New York, NY          1.690000e+12  ComplexOnsiteApply          0
# 3             Forney, TX          1.690000e+12  ComplexOnsiteApply          0
# 4           New York, NY          1.690000e+12  ComplexOnsiteApply          1
# ...                  ...                   ...                 ...        ...
# 15881  West Columbia, SC          1.690000e+12        OffsiteApply          0
# 15882        Teaneck, NJ          1.690000e+12        OffsiteApply          0
# 15883        Teaneck, NJ          1.690000e+12        OffsiteApply          0
# 15884       New York, NY          1.690000e+12        OffsiteApply          0
# 15885      Vicksburg, MS          1.690000e+12  ComplexOnsiteApply          0
#
#                                            description_y  company_size  \
# 0                                                    NaN           NaN
# 1      CargoLogin is a freight and logistics company ...           1.0
# 2      Employvision is a talent acquisition and manag...           1.0
# 3                                                    NaN           2.0
# 4      Ken Fulk Inc, is a creative think tank based o...           1.0
# ...                                                  ...           ...
# 15881  Aspire Bakeries is a North American baking com...           5.0
# 15882  Holy Name is a fully accredited, not-for-profi...           5.0
# 15883  Holy Name is a fully accredited, not-for-profi...           5.0
# 15884  Columbia University Irving Medical Center (CUI...           7.0
# 15885  Your local leader in nursing & rehabilitation ...           5.0
#
#                                                 industry
# 0                                                    NaN
# 1                       Transportation/Trucking/Railroad
# 2                                  Staffing & Recruiting
# 3                                 Religious Institutions
# 4                                                 Design
# ...                                                  ...
# 15881  Food Production, Food Production, Food Product...
# 15882     Hospital & Health Care, Hospital & Health Care
# 15883     Hospital & Health Care, Hospital & Health Care
# 15884                             Hospital & Health Care
# 15885                             Hospital & Health Care
#
# [15886 rows x 11 columns]

# %%
pretty_column_name = {'title': 'job_title', 'name': 'company_name', 'description_x': 'job_description',
               'formatted_work_type': 'work_type','original_listed_time': 'listed_time','description_y': 'company_description'}
data = merged_data.rename(columns=pretty_column_name)
data = data.dropna()
data
# Out:
#                                    job_title  \
# 1                              Sales Manager
# 2                         Model Risk Auditor
# 4                        NY Studio Assistant
# 5                           Office Associate
# 6                          Education Manager
# ...                                      ...
# 15881                  Sanitation Technician
# 15882                         Unit Secretary
# 15883                Radiology Aide, Perdiem
# 15884                            MRI Manager
# 15885  Area Director of Business Development
#
#                                     company_name  \
# 1                                    CargoLogin.
# 2                              Employvision Inc.
# 4                                   Ken Fulk Inc
# 5                                Sunnyland Farms
# 6                       Paradigm Senior Services
# ...                                          ...
# 15881                            Aspire Bakeries
# 15882                   Holy Name Medical Center
# 15883                   Holy Name Medical Center
# 15884  Columbia University Irving Medical Center
# 15885                              Nexion Health
#
#                                          job_description  work_type  \
# 1      Are you a dynamic and creative marketing profe...  Full-time
# 2      Join Us as a Model Risk Auditor – Showcase You...   Contract
# 4      YOU COULD BE ONE OF THE MAGIC MAKERS\nKen Fulk...  Full-time
# 5      Provide clerical and administrative support to...  Full-time
# 6      Company Snapshot Headquartered in North Miami,...  Full-time
# ...                                                  ...        ...
# 15881  Location:\n\nWest Columbia, SC, US, 29172\n\n2...  Part-time
# 15882  Job Title: Unit Secretary\nDepartment: Nursing...  Full-time
# 15883  Job Title: Radiology Aide, Perdiem\nDepartment...  Part-time
# 15884  Grade 105\nJob Type: Officer of Administration...  Full-time
# 15885  Nexion Health Management affiliates operate 56...  Full-time
#
#                 location   listed_time    application_type  sponsored  \
# 1      Santa Clarita, CA  1.690000e+12  ComplexOnsiteApply          0
# 2           New York, NY  1.690000e+12  ComplexOnsiteApply          0
# 4           New York, NY  1.690000e+12  ComplexOnsiteApply          1
# 5             Albany, GA  1.690000e+12  ComplexOnsiteApply          1
# 6          United States  1.690000e+12        OffsiteApply          0
# ...                  ...           ...                 ...        ...
# 15881  West Columbia, SC  1.690000e+12        OffsiteApply          0
# 15882        Teaneck, NJ  1.690000e+12        OffsiteApply          0
# 15883        Teaneck, NJ  1.690000e+12        OffsiteApply          0
# 15884       New York, NY  1.690000e+12        OffsiteApply          0
# 15885      Vicksburg, MS  1.690000e+12  ComplexOnsiteApply          0
#
#                                      company_description  company_size  \
# 1      CargoLogin is a freight and logistics company ...           1.0
# 2      Employvision is a talent acquisition and manag...           1.0
# 4      Ken Fulk Inc, is a creative think tank based o...           1.0
# 5      Here at Sunnyland Farms we have been growing a...           2.0
# 6      Paradigm provides a full back office solution ...           2.0
# ...                                                  ...           ...
# 15881  Aspire Bakeries is a North American baking com...           5.0
# 15882  Holy Name is a fully accredited, not-for-profi...           5.0
# 15883  Holy Name is a fully accredited, not-for-profi...           5.0
# 15884  Columbia University Irving Medical Center (CUI...           7.0
# 15885  Your local leader in nursing & rehabilitation ...           5.0
#
#                                                 industry
# 1                       Transportation/Trucking/Railroad
# 2                                  Staffing & Recruiting
# 4                                                 Design
# 5                                                 Retail
# 6                                      Computer Software
# ...                                                  ...
# 15881  Food Production, Food Production, Food Product...
# 15882     Hospital & Health Care, Hospital & Health Care
# 15883     Hospital & Health Care, Hospital & Health Care
# 15884                             Hospital & Health Care
# 15885                             Hospital & Health Care
#
# [14734 rows x 11 columns]

# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %%
# Create a word cloud from job titles
job_titles_text = ' '.join(data['job_title'])
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(job_titles_text)

# Display the word cloud
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('Job Title Word Cloud')
plt.axis('off')
plt.tight_layout()
plt.show()

# %%
# Visualization 2: Company Size Distribution (Pie Chart)
company_size_counts = data['company_size'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(company_size_counts, labels=company_size_counts.index, autopct='%1.1f%%', colors=['lightcoral', 'lightgreen', 'lightblue'])
plt.title('Company Size Distribution')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
# Visualization 3: Job Type Breakdown (Bar Chart)
job_type_counts = data['work_type'].value_counts()
plt.figure(figsize=(10, 6))
job_type_counts.plot(kind='bar', color='lightseagreen')
plt.title('Job Type Breakdown')
plt.xlabel('Job Type')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Visualization 6: Sponsored vs. Non-Sponsored Listings (Pie Chart)
sponsored_counts = data['sponsored'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(sponsored_counts, labels=['Non-Sponsored', 'Sponsored'], autopct='%1.1f%%', colors=['lightblue', 'lightgreen'])
plt.title('Sponsored vs. Non-Sponsored Listings')
plt.axis('equal')
plt.tight_layout()
plt.show()
